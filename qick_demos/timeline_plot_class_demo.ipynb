# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RangeSlider
# %matplotlib widget
#import plotly.graph_objects as go
#import plotly.express as px
import numpy as np
import timeline as tl

# %%
tl_1 = tl.timeline("01_phase_calibration")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [ -20 2102]
# 2102
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_00a = tl.timeline("00a")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [-20 352]
# 352
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_00c = tl.timeline("00c")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(8.8, 5), constrained_layout=True)
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [-20 412]
# 412
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_00d = tl.timeline("00d")
# Out:
# [-20 312]
# 312
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_00e = tl.timeline("00e")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [ -20 2292]
# 2292
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_00f = tl.timeline("00f")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [ -20 2292]
# 2292
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_03 = tl.timeline("03")
# Out:
# [-20 312]
# 312
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_03a = tl.timeline("03a")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [-20 312]
# 312
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_03b = tl.timeline("03b")
# Out:
# [-20 312]
# 312
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_cj = tl.timeline("conditional_logic")
# Out:
# [-20 312]
# 312
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tl_from_man = tl.timeline("from_man")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:31: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [-20 702]
# 702
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
