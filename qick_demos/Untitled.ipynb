# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RangeSlider
# %matplotlib widget
#import plotly.graph_objects as go
#import plotly.express as px
import numpy as np
import timeline as tl

# %%
tl_1 = tl.timeline("01_phase_calibration")
# Out:
# /Users/keshavkapoor/Documents/qick_interpreter/qick_demos/timeline.py:41: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(bottom=0.25)
# [ -20 4330]
# 4330
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
